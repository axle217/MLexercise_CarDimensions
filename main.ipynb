# %%
# Setup for Google Colab directories
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks')
# %cd MLexercise_CarDimensions

import glob
import re
import pandas as pd

file_paths = glob.glob("data/2*_en.csv")
file_paths.sort(key=lambda x: int(re.search(r'\d+', x).group()))
file_paths

dataframes = [pd.read_csv(path, encoding='ISO-8859-1') for path in file_paths]
# Out:
# /content/drive/MyDrive/Colab Notebooks/MLexercise_CarDimensions
# ['data/2011_en.csv',
#  'data/2012_en.csv',
#  'data/2013_en.csv',
#  'data/2014_en.csv',
#  'data/2015_en.csv',
#  'data/2016_en.csv',
#  'data/2017_en.csv',
#  'data/2018_en.csv',
#  'data/2019_en.csv',
#  'data/2021_en.csv',
#  'data/2022_en.csv',
#  'data/2023_en.csv']

# %%
dataframes[0]

# %%
# Data cleaning
cleaned_dataframes = [df.dropna() for df in dataframes]
cleaned_dataframes = [df.drop_duplicates() for df in dataframes]

merged_data = pd.concat(dataframes)
# merged_data

# %%
# merged_data =
merged_data.rename(columns={"MYR": "Model Year",
                            "OL": "Overall Length",
                            "OW": "Overall Width",
                            "OH": "Overall Height",
                            "WB": "Wheelbase",
                            "CW": "Curb Weight",
                            "A": "Front End Length",
                            "B": "Rear End Length",
                            "C": "Side Glass Height",
                            "D": "Body Side Height",
                            "E": "Roof Width",
                            "F": "Front Overhang",
                            "G": "Rear Overhang",
                            "TWF": "Track Width Front",
                            "TWR": "Track Width Rear",
                            "WDIST": "Track Width"
})
merged_data.rename(columns={"MYR": "Model Year",
                                          "OH": "Overall Height",
                                          "CW": "Curb Weight",
                                          "TWR": "Track Width Rear"
                                          })
# Out:
#            MAKE                            MODEL  Model Year     OL     OW  \
# 0         ACURA  CSX 4DR SEDAN FWD /TECH PACKAGE           6  454.0  175.0
# 1         ACURA      MDX 4DR SUV AWD /TECH/ELITE          10  485.0  199.0
# 2         ACURA    RDX 4DR SUV AWD /TECH PACKAGE          10  462.0  187.0
# 3         ACURA          RL 4DR SEDAN AWD /ELITE           9  497.0  185.0
# 4         ACURA     TL 4 DR SEDAN FWD/TECHNOLOGY           9  497.0  188.0
# ..          ...                              ...         ...    ...    ...
# 104  VOLKSWAGEN                   GOLF 4DR HATCH          22  429.0  179.0
# 105  VOLKSWAGEN                        I.D. Buzz          22  471.0  199.0
# 106  VOLKSWAGEN                 TAOS 4DR SUV AWD          22  447.0  185.0
# 107  VOLKSWAGEN                 TAOS 4DR SUV FWD          22  447.0  185.0
# 108  VOLKSWAGEN                     ID.4 4DR SUV          22  458.0  185.0
#
#        OH    WB     CW       A      B     C     D      E      F      G    TWF  \
# 0    144.0  270  1300.0   94.0   45.0  36.0  76.0  110.0   92.0   93.0  150.0
# 1    173.0  275  2064.0  117.0  183.0  42.0  85.0  126.0  100.0  110.0  172.0
# 2    166.0  265  1790.0  125.0  152.0  38.0  84.0  124.0   98.0   99.0  158.0
# 3    146.0  280  1864.0  125.0   73.0  37.0  80.0  116.0  104.0  111.0  157.0
# 4    145.0  278  1682.0  134.0   62.0  34.0  81.0  117.0  105.0  115.0  160.0
# ..     ...  ...     ...    ...    ...   ...   ...    ...    ...    ...    ...
# 104  146.0  263     NaN  116.0  142.0  37.0  77.0  105.0   88.0   78.0  153.0
# 105  194.0  299     NaN    NaN    NaN   NaN   NaN    NaN    NaN    NaN    NaN
# 106  164.0  269  1556.0  177.0  159.0  36.0  84.0  102.0   91.0   87.0  157.0
# 107  164.0  269  1440.0  177.0  159.0  36.0  84.0  102.0   91.0   87.0  157.0
# 108  164.0  277  2068.0    NaN    NaN   NaN   NaN    NaN    NaN    NaN  159.0
#
#       TWR   WDIST
# 0    151.0  61/39
# 1    172.0  56/44
# 2    159.0  57/43
# 3    157.0  58/42
# 4    161.0  61/39
# ..     ...    ...
# 104  151.0    NaN
# 105    NaN    NaN
# 106  154.0  59/49
# 107  154.0  59/49
# 108  157.0  50/50
#
# [10665 rows x 18 columns]

# %%
merged_data
# Out:
#            MAKE                            MODEL  Model Year  Overall Length  \
# 0         ACURA  CSX 4DR SEDAN FWD /TECH PACKAGE           6           454.0
# 1         ACURA      MDX 4DR SUV AWD /TECH/ELITE          10           485.0
# 2         ACURA    RDX 4DR SUV AWD /TECH PACKAGE          10           462.0
# 3         ACURA          RL 4DR SEDAN AWD /ELITE           9           497.0
# 4         ACURA     TL 4 DR SEDAN FWD/TECHNOLOGY           9           497.0
# ..          ...                              ...         ...             ...
# 104  VOLKSWAGEN                   GOLF 4DR HATCH          22           429.0
# 105  VOLKSWAGEN                        I.D. Buzz          22           471.0
# 106  VOLKSWAGEN                 TAOS 4DR SUV AWD          22           447.0
# 107  VOLKSWAGEN                 TAOS 4DR SUV FWD          22           447.0
# 108  VOLKSWAGEN                     ID.4 4DR SUV          22           458.0
#
#      Overall Width    OH  Wheelbase     CW   Front End Length  \
# 0            175.0  144.0       270  1300.0              94.0
# 1            199.0  173.0       275  2064.0             117.0
# 2            187.0  166.0       265  1790.0             125.0
# 3            185.0  146.0       280  1864.0             125.0
# 4            188.0  145.0       278  1682.0             134.0
# ..             ...    ...       ...     ...               ...
# 104          179.0  146.0       263     NaN             116.0
# 105          199.0  194.0       299     NaN               NaN
# 106          185.0  164.0       269  1556.0             177.0
# 107          185.0  164.0       269  1440.0             177.0
# 108          185.0  164.0       277  2068.0               NaN
#
#      Rear End Length  Side Glass Height  Body Side Height  Roof Width  \
# 0               45.0               36.0              76.0       110.0
# 1              183.0               42.0              85.0       126.0
# 2              152.0               38.0              84.0       124.0
# 3               73.0               37.0              80.0       116.0
# 4               62.0               34.0              81.0       117.0
# ..               ...                ...               ...         ...
# 104            142.0               37.0              77.0       105.0
# 105              NaN                NaN               NaN         NaN
# 106            159.0               36.0              84.0       102.0
# 107            159.0               36.0              84.0       102.0
# 108              NaN                NaN               NaN         NaN
#
#      Front Overhang  Rear Overhang  Track Width Front   TWR  Track Width
# 0              92.0           93.0              150.0  151.0       61/39
# 1             100.0          110.0              172.0  172.0       56/44
# 2              98.0           99.0              158.0  159.0       57/43
# 3             104.0          111.0              157.0  157.0       58/42
# 4             105.0          115.0              160.0  161.0       61/39
# ..              ...            ...                ...    ...         ...
# 104            88.0           78.0              153.0  151.0         NaN
# 105             NaN            NaN                NaN    NaN         NaN
# 106            91.0           87.0              157.0  154.0       59/49
# 107            91.0           87.0              157.0  154.0       59/49
# 108             NaN            NaN              159.0  157.0       50/50
#
# [10665 rows x 18 columns]
