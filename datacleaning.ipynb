# %%
# Setup directories for Google Colab
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks')
# %cd MLexercise_CarDimensions

import glob
import re
import pandas as pd

# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)

file_paths = glob.glob("data/2*_en.csv")
file_paths.sort(key=lambda x: int(re.search(r'\d+', x).group()))
print(file_paths)

dataframes = [pd.read_csv(path, encoding='ISO-8859-1') for path in file_paths]
# Out:
# /content/drive/MyDrive/Colab Notebooks/MLexercise_CarDimensions
# ['data/2011_en.csv', 'data/2012_en.csv', 'data/2013_en.csv', 'data/2014_en.csv', 'data/2015_en.csv', 'data/2016_en.csv', 'data/2017_en.csv', 'data/2018_en.csv', 'data/2019_en.csv', 'data/2020_en.csv', 'data/2021_en.csv', 'data/2022_en.csv', 'data/2023_en.csv']

# %%
removed_NaN_dataframes = [df.dropna() for df in dataframes]

merged_data = pd.concat(removed_NaN_dataframes)
# Remove unnecessary white spaces in string type entries
merged_data = merged_data.map(
    lambda x: x.strip().replace('\xa0', '') if isinstance(x, str) else x
)

# %%
# Check for white spaces in label
print(merged_data.columns.tolist())
merged_data.columns = (
    merged_data.columns
    .str.strip()  # Remove leading/trailing whitespace
    .str.replace('\xa0', '', regex=False)  # Remove non-breaking spaces
    # .str.replace(' ', '_')  # Replace spaces with underscores
)
print(merged_data.columns.tolist())

merged_data = merged_data.rename(columns={"MYR": "Model Year",
                            "OL": "Overall Length",
                            "OW": "Overall Width",
                            "OH": "Overall Height",
                            "WB": "Wheelbase",
                            "CW": "Curb Weight",
                            "A": "Front End Length",
                            "B": "Rear End Length",
                            "C": "Side Glass Height",
                            "D": "Body Side Height",
                            "E": "Roof Width",
                            "F": "Front Overhang",
                            "G": "Rear Overhang",
                            "TWF": "Track Width Front",
                            "TWR": "Track Width Rear",
                            "WDIST": "Weight Distribution"
})

print(merged_data.columns.tolist())
# Out:
# ['MAKE', 'MODEL', 'MYR', 'OL', 'OW', 'OH ', 'WB', 'CW ', 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'TWF', 'TWR ', 'WDIST']
# ['MAKE', 'MODEL', 'MYR', 'OL', 'OW', 'OH', 'WB', 'CW', 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'TWF', 'TWR', 'WDIST']
# ['MAKE', 'MODEL', 'Model Year', 'Overall Length', 'Overall Width', 'Overall Height', 'Wheelbase', 'Curb Weight', 'Front End Length', 'Rear End Length', 'Side Glass Height', 'Body Side Height', 'Roof Width', 'Front Overhang', 'Rear Overhang', 'Track Width Front', 'Track Width Rear', 'Weight Distribution']

# %%
merged_data = merged_data.sort_values(by=['MODEL'])
merged_data
# Out:
#       MAKE                        MODEL  Model Year  Overall Length  \
# 56     BMW  1 SERIES 128i 2DR COUPE RWD           8           437.0
# 58     BMW  1 SERIES 128i 2DR COUPE RWD           8           437.0
# 53     BMW  1 SERIES 128i 2DR COUPE RWD           8           437.0
# 57     BMW  1 SERIES 135i 2DR COUPE RWD           8           437.0
# 59     BMW  1 SERIES 135i 2DR COUPE RWD           8           437.0
# ..     ...                          ...         ...             ...
# 751  SCION            xD 4 DR HATCHBACK          11           393.0
# 801  SCION            xD 4 DR HATCHBACK          11           393.0
# 783  SCION            xD 4 DR HATCHBACK          11           393.0
# 787  SCION             xD 4DR HATCHBACK          11           393.0
# 873  SCION             xD 4DR HATCHBACK          11           393.0
#
#      Overall Width  Overall Height Wheelbase  Curb Weight  Front End Length  \
# 56           175.0           141.0       266       1455.0             124.0
# 58           175.0           141.0       266       1455.0             124.0
# 53           175.0           141.0       266       1478.0             124.0
# 57           175.0           141.0       266       1530.0             124.0
# 59           175.0           141.0       266       1530.0             124.0
# ..             ...             ...       ...          ...               ...
# 751          173.0           151.0       246       1190.0              90.0
# 801          173.0           151.0       246       1190.0              90.0
# 783          173.0           151.0       246       1190.0              90.0
# 787          173.0           151.0       246       1209.0              90.0
# 873          173.0           151.0       246       1191.0              90.0
#
#      Rear End Length  Side Glass Height  Body Side Height  Roof Width  \
# 56              50.0               35.0              80.0       107.0
# 58              50.0               35.0              80.0       107.0
# 53              50.0               35.0              80.0       107.0
# 57              50.0               35.0              80.0       107.0
# 59              50.0               35.0              80.0       107.0
# ..               ...                ...               ...         ...
# 751            137.0               35.0              84.0       103.0
# 801            137.0               35.0              84.0       103.0
# 783            137.0               35.0              84.0       103.0
# 787            137.0               35.0              84.0       103.0
# 873            137.0               35.0              84.0       103.0
#
#      Front Overhang  Rear Overhang  Track Width Front  Track Width Rear  \
# 56             77.0           96.0              146.0             148.0
# 58             77.0           96.0              146.0             148.0
# 53             77.0           96.0              146.0             148.0
# 57             77.0           96.0              146.0             148.0
# 59             77.0           96.0              146.0             148.0
# ..              ...            ...                ...               ...
# 751            78.0           68.0              149.0             149.0
# 801            78.0           68.0              149.0             149.0
# 783            78.0           68.0              149.0             149.0
# 787            78.0           68.0              149.0             149.0
# 873            78.0           68.0              149.0             149.0
#
#     Weight Distribution
# 56                52/48
# 58                52/48
# 53                52/48
# 57                52/48
# 59                52/48
# ..                  ...
# 751               60/40
# 801               60/40
# 783               60/40
# 787               60/40
# 873               60/40
#
# [8559 rows x 18 columns]

# %%
merged_data = merged_data.drop_duplicates()
merged_data
# Out:
#       MAKE                        MODEL  Model Year  Overall Length  \
# 56     BMW  1 SERIES 128i 2DR COUPE RWD           8           437.0
# 53     BMW  1 SERIES 128i 2DR COUPE RWD           8           437.0
# 57     BMW  1 SERIES 135i 2DR COUPE RWD           8           437.0
# 54     BMW  1 SERIES 135i 2DR COUPE RWD           8           437.0
# 60     BMW   1-SERIES M COUPE 2DR COUPE          11           438.0
# ..     ...                          ...         ...             ...
# 872  SCION                   xB 4DR SUV          14           427.0
# 751  SCION            xD 4 DR HATCHBACK          11           393.0
# 801  SCION            xD 4 DR HATCHBACK          11           393.0
# 787  SCION             xD 4DR HATCHBACK          11           393.0
# 873  SCION             xD 4DR HATCHBACK          11           393.0
#
#      Overall Width  Overall Height Wheelbase  Curb Weight  Front End Length  \
# 56           175.0           141.0       266       1455.0             124.0
# 53           175.0           141.0       266       1478.0             124.0
# 57           175.0           141.0       266       1530.0             124.0
# 54           175.0           141.0       266       1533.0             124.0
# 60           180.0           142.0       266       1525.0             131.0
# ..             ...             ...       ...          ...               ...
# 872          176.0           161.0       260       1373.0             103.0
# 751          173.0           151.0       246       1190.0              90.0
# 801          173.0           151.0       246       1190.0              90.0
# 787          173.0           151.0       246       1209.0              90.0
# 873          173.0           151.0       246       1191.0              90.0
#
#      Rear End Length  Side Glass Height  Body Side Height  Roof Width  \
# 56              50.0               35.0              80.0       107.0
# 53              50.0               35.0              80.0       107.0
# 57              50.0               35.0              80.0       107.0
# 54              50.0               35.0              80.0       107.0
# 60              54.0               35.0              81.0       105.0
# ..               ...                ...               ...         ...
# 872            153.0               36.0              90.0       123.0
# 751            137.0               35.0              84.0       103.0
# 801            137.0               35.0              84.0       103.0
# 787            137.0               35.0              84.0       103.0
# 873            137.0               35.0              84.0       103.0
#
#      Front Overhang  Rear Overhang  Track Width Front  Track Width Rear  \
# 56             77.0           96.0              146.0             148.0
# 53             77.0           96.0              146.0             148.0
# 57             77.0           96.0              146.0             148.0
# 54             77.0           96.0              146.0             148.0
# 60             77.0           95.0              154.0             154.0
# ..              ...            ...                ...               ...
# 872            87.0           80.0              153.0             152.0
# 751            78.0           68.0              149.0             149.0
# 801            78.0           68.0              149.0             149.0
# 787            78.0           68.0              149.0             149.0
# 873            78.0           68.0              149.0             149.0
#
#     Weight Distribution
# 56                52/48
# 53                52/48
# 57                52/48
# 54                52/48
# 60                50/50
# ..                  ...
# 872               63/37
# 751               60/40
# 801               60/40
# 787               60/40
# 873               60/40
#
# [4200 rows x 18 columns]

# %%
merged_data.info()
# print(merged_data.dtypes)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4200 entries, 56 to 873
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   MAKE                 4200 non-null   object
#  1   MODEL                4200 non-null   object
#  2   Model Year           4200 non-null   int64
#  3   Overall Length       4200 non-null   float64
#  4   Overall Width        4200 non-null   float64
#  5   Overall Height       4200 non-null   float64
#  6   Wheelbase            4200 non-null   object
#  7   Curb Weight          4200 non-null   float64
#  8   Front End Length     4200 non-null   float64
#  9   Rear End Length      4200 non-null   float64
#  10  Side Glass Height    4200 non-null   float64
#  11  Body Side Height     4200 non-null   float64
#  12  Roof Width           4200 non-null   float64
#  13  Front Overhang       4200 non-null   float64
#  14  Rear Overhang        4200 non-null   float64
#  15  Track Width Front    4200 non-null   float64
#  16  Track Width Rear     4200 non-null   float64
#  17  Weight Distribution  4200 non-null   object
# dtypes: float64(13), int64(1), object(4)
# memory usage: 623.4+ KB

# %%
print(merged_data['MAKE'].unique())
print(merged_data['MODEL'].unique())
print(merged_data['Wheelbase'].unique())
# Out:
# ['BMW' 'FIAT' 'RAM TRUCKS' 'CHEVROLET' 'GMC' 'CHRYSLER' 'MINI' 'NISSAN'
#  'ALFA ROMEO' 'TOYOTA' 'MAZDA' 'MCLAREN' 'PORSCHE' 'SAAB' 'AUDI' 'HYUNDAI'
#  'HONDA' 'MERCEDES-BENZ' 'MERCEDES-AMG' 'VOLKSWAGEN' 'SUBARU' 'CADILLAC'
#  'DODGE' 'LINCOLN' 'KIA' 'FORD' 'VOLVO' 'JEEP' 'ACURA' 'LEXUS'
#  'ASTON MARTIN' 'LAND ROVER' 'JAGUAR' 'MITSUBISHI' 'LOTUS' 'BUICK'
#  'INFINITI' 'SMART' 'SCION' 'GENESIS' 'MASERATI' 'SUZUKI' 'FISKER' 'TESLA'
#  'LAMBORGHINI' 'SRT']
# ['1 SERIES 128i 2DR COUPE RWD' '1 SERIES 135i 2DR COUPE RWD'
#  '1-SERIES M COUPE 2DR COUPE' ... 'xB 4DR SUV' 'xD 4 DR HATCHBACK'
#  'xD 4DR HATCHBACK']
# [266 '266' 231 367.0 390.0 343 '343' 357 269 268 267.0 274.0 275 '277' 277
#  394 '394' 429.0 379 407 250.0 281 '276' 292 291 276 285.0 305 '305' 255
#  '255' 286 238 '279' 279 257 298 297 '297' 307 '307' 230 '230' 261 '278'
#  321 '321' 248.0 282 303.0 '268' '281' '284' 245.0 '233' 235 '235' '258'
#  258 264 260 '275' 283.0 293.0 '299' 299 '312' 312 302 '302' '250' 272
#  '274' 278 '280' 280 263 313 308 '313' 284 289 331 '331' 287.0 '282' '248'
#  270 254 '290' 241 '241' 295.0 265 '264' '285' 326.0 320 '320' 309.0 290
#  271 '295' 273.0 '265' 262 '270' 296 '296' 247 '247' '260' '269' '262' 244
#  '244' 310 311 288 '288' 253 '254' '333' '334' '293' 304 '304' 294 '287'
#  351 '351' 252 256.0 '286' 330 '330' 341.0 334 333 358 368 359.0 416 414
#  398 369.0 417.0 399.0 371 370.0 249 '249' 300 '300' '261' 187 '187' 355.0
#  '319' 319 '273' '289' 301.0 317 316.0 '294' '308' 349 '292' '263' '271'
#  '256' '253' '309' '283' '272' '267' 322 '322' 306 '356' 356 318.0 '310'
#  '317' '303' 389 365 374.0 '365' 400 '400' 338 '338' 437.0 404 '243' 239
#  324 '357' '326' 325 '325' 405 '405' '355' 385 375.0 251 '246' '370' 418.0
#  242 '242' 246.0 '291' '316' 200]

# %%
# Convert mixed string to numeric
# merged_data['Wheelbase'] = pd.to_numeric(merged_data['Wheelbase'], errors='coerce') # This gives warning
merged_data.loc[:, 'Wheelbase'] = pd.to_numeric(merged_data['Wheelbase'], errors='coerce')
print(merged_data['Wheelbase'].unique())

# merged_data['MAKE'] = merged_data['MAKE'].astype(str)
# print(merged_data['MAKE'].unique())

print(merged_data.dtypes)

merged_data = merged_data.drop_duplicates()
# Out:
# [266.0 231.0 367.0 390.0 343.0 357.0 269.0 268.0 267.0 274.0 275.0 277.0
#  394.0 429.0 379.0 407.0 250.0 281.0 276.0 292.0 291.0 285.0 305.0 255.0
#  286.0 238.0 279.0 257.0 298.0 297.0 307.0 230.0 261.0 278.0 321.0 248.0
#  282.0 303.0 284.0 245.0 233.0 235.0 258.0 264.0 260.0 283.0 293.0 299.0
#  312.0 302.0 272.0 280.0 263.0 313.0 308.0 289.0 331.0 287.0 270.0 254.0
#  290.0 241.0 295.0 265.0 326.0 320.0 309.0 271.0 273.0 262.0 296.0 247.0
#  244.0 310.0 311.0 288.0 253.0 333.0 334.0 304.0 294.0 351.0 252.0 256.0
#  330.0 341.0 358.0 368.0 359.0 416.0 414.0 398.0 369.0 417.0 399.0 371.0
#  370.0 249.0 300.0 187.0 355.0 319.0 301.0 317.0 316.0 349.0 322.0 306.0
#  356.0 318.0 389.0 365.0 374.0 400.0 338.0 437.0 404.0 243.0 239.0 324.0
#  325.0 405.0 385.0 375.0 251.0 246.0 418.0 242.0 200.0]
# MAKE                    object
# MODEL                   object
# Model Year               int64
# Overall Length         float64
# Overall Width          float64
# Overall Height         float64
# Wheelbase               object
# Curb Weight            float64
# Front End Length       float64
# Rear End Length        float64
# Side Glass Height      float64
# Body Side Height       float64
# Roof Width             float64
# Front Overhang         float64
# Rear Overhang          float64
# Track Width Front      float64
# Track Width Rear       float64
# Weight Distribution     object
# dtype: object

# %%
merged_data
# Same model, different curb weight or other features
# Out:
#       MAKE                        MODEL  Model Year  Overall Length  \
# 56     BMW  1 SERIES 128i 2DR COUPE RWD           8           437.0
# 53     BMW  1 SERIES 128i 2DR COUPE RWD           8           437.0
# 57     BMW  1 SERIES 135i 2DR COUPE RWD           8           437.0
# 54     BMW  1 SERIES 135i 2DR COUPE RWD           8           437.0
# 60     BMW   1-SERIES M COUPE 2DR COUPE          11           438.0
# ..     ...                          ...         ...             ...
# 786  SCION                   xB 4DR SUV          14           427.0
# 872  SCION                   xB 4DR SUV          14           427.0
# 751  SCION            xD 4 DR HATCHBACK          11           393.0
# 787  SCION             xD 4DR HATCHBACK          11           393.0
# 873  SCION             xD 4DR HATCHBACK          11           393.0
#
#      Overall Width  Overall Height Wheelbase  Curb Weight  Front End Length  \
# 56           175.0           141.0     266.0       1455.0             124.0
# 53           175.0           141.0     266.0       1478.0             124.0
# 57           175.0           141.0     266.0       1530.0             124.0
# 54           175.0           141.0     266.0       1533.0             124.0
# 60           180.0           142.0     266.0       1525.0             131.0
# ..             ...             ...       ...          ...               ...
# 786          176.0           161.0     260.0       1399.0             103.0
# 872          176.0           161.0     260.0       1373.0             103.0
# 751          173.0           151.0     246.0       1190.0              90.0
# 787          173.0           151.0     246.0       1209.0              90.0
# 873          173.0           151.0     246.0       1191.0              90.0
#
#      Rear End Length  Side Glass Height  Body Side Height  Roof Width  \
# 56              50.0               35.0              80.0       107.0
# 53              50.0               35.0              80.0       107.0
# 57              50.0               35.0              80.0       107.0
# 54              50.0               35.0              80.0       107.0
# 60              54.0               35.0              81.0       105.0
# ..               ...                ...               ...         ...
# 786            153.0               36.0              90.0       123.0
# 872            153.0               36.0              90.0       123.0
# 751            137.0               35.0              84.0       103.0
# 787            137.0               35.0              84.0       103.0
# 873            137.0               35.0              84.0       103.0
#
#      Front Overhang  Rear Overhang  Track Width Front  Track Width Rear  \
# 56             77.0           96.0              146.0             148.0
# 53             77.0           96.0              146.0             148.0
# 57             77.0           96.0              146.0             148.0
# 54             77.0           96.0              146.0             148.0
# 60             77.0           95.0              154.0             154.0
# ..              ...            ...                ...               ...
# 786            87.0           80.0              153.0             152.0
# 872            87.0           80.0              153.0             152.0
# 751            78.0           68.0              149.0             149.0
# 787            78.0           68.0              149.0             149.0
# 873            78.0           68.0              149.0             149.0
#
#     Weight Distribution
# 56                52/48
# 53                52/48
# 57                52/48
# 54                52/48
# 60                50/50
# ..                  ...
# 786               63/37
# 872               63/37
# 751               60/40
# 787               60/40
# 873               60/40
#
# [3828 rows x 18 columns]

# %%
merged_data.to_csv("data/cleaned_data.csv", index=False)
